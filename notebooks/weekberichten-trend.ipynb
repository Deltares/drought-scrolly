# %%
import pathlib
import datetime
import warnings

from tqdm.notebook import tqdm

import shapely.geometry
import geopandas as gpd
import pandas as pd
import numpy as np
import movingpandas as mpd

import matplotlib.pyplot as plt
import statsmodels.api as sm
import matplotlib.dates
import matplotlib.cm

plt.style.use('dark_background')

warnings.filterwarnings('ignore')

# %%
data_dir = pathlib.Path('/Users/baart_f/data/drought/ivs').expanduser()
ivs_df = pd.read_excel(data_dir / 'IVSdata_plots.xlsx', sheet_name='gewicht_reis_per_week', header=5)

# %%
ivs_df['t'] = ivs_df.week.apply(lambda w: datetime.datetime.strptime(f"2022-W{w}-1", "%Y-W%W-%w"))

# %%
fig, ax = plt.subplots()
ax.stackplot(ivs_df['t'], ivs_df.Duwstellen, ivs_df.Koppelverbanden, ivs_df.Motorvrachtschepen, labels=('Duwstellen', 'Koppelverbanden', 'Motorvracht')) 
ax.legend()
ax.set_ylabel('Getransporteerde lading [ton/week]')
ax.set_xlabel('Tijd')
ax.legend(loc='upper left')

fig.suptitle('Lading transport tussen Rotterdam en Duitsland')
fig.tight_layout()
ax.set_xticks([datetime.datetime(2022, 1, 1), datetime.datetime(2022, 4, 1), datetime.datetime(2022, 7, 1), datetime.datetime(2022, 10, 1)])
ax.set_xlim(datetime.datetime(2022, 1, 1), datetime.datetime(2022, 10, 1)) 

fig.savefig('/Users/baart_f/src/drought-scrolly/example/drought-scrolly/images/figures/ivs-trends_ship.png')

# %%
reizen_df = pd.read_excel(data_dir / 'IVSdata_plots.xlsx', sheet_name='aantal_reizen_per_week', header=5)
reizen_df['t'] = reizen_df.week.apply(lambda w: datetime.datetime.strptime(f"2022-W{w}-1", "%Y-W%W-%w"))
reizen_df.head()
# Out:
#    week  Duwstellen  Koppelverbanden  Motorvrachtschepen          t
# 0     1        1519              687                1244 2022-01-03
# 1     2        1505              185                1552 2022-01-10
# 2     3         700              491                1411 2022-01-17
# 3     4         707              354                1205 2022-01-24
# 4     5         853              705                1320 2022-01-31

# %%
fig, ax = plt.subplots()
ax.stackplot(ivs_df['t'], reizen_df.Duwstellen, reizen_df.Koppelverbanden, reizen_df.Motorvrachtschepen, labels=('Duwstellen', 'Koppelverbanden', 'Motorvracht')) 
ax.legend()
ax.set_ylabel('Aantal trips [trips/week]')
ax.set_xlabel('Tijd')
ax.legend(loc='upper left')
fig.suptitle('Vervoersbewegingen tussen Rotterdam en Duitsland')
fig.tight_layout()
ax.set_xticks([datetime.datetime(2022, 1, 1), datetime.datetime(2022, 4, 1), datetime.datetime(2022, 7, 1), datetime.datetime(2022, 10, 1)])
ax.set_xlim(datetime.datetime(2022, 1, 1), datetime.datetime(2022, 10, 1)) 
fig.savefig('/Users/baart_f/src/drought-scrolly/example/drought-scrolly/images/figures/ivs-trips-trends.png')
